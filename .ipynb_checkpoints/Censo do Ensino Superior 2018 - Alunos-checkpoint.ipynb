# %% [markdown]
# ## Title
#
# > Sources:
# - http://download.inep.gov.br/microdados/microdados_educacao_superior_2018.zip
# - http://emec.mec.gov.br/

# %%
import numpy as np
import pandas as pd
import os
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
alunos_df = pd.read_csv('DM_ALUNO.csv', sep='|')
# Out:
# C:\Users\ROLD003\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
alunos_df.head(10)
# Out:
#    NU_ANO_CENSO  CO_IES  TP_CATEGORIA_ADMINISTRATIVA  \
# 0          2018       1                            1
# 1          2018       1                            1
# 2          2018       1                            1
# 3          2018       1                            1
# 4          2018       1                            1
# 5          2018       1                            1
# 6          2018       1                            1
# 7          2018       1                            1
# 8          2018       1                            1
# 9          2018       1                            1
#
#    TP_ORGANIZACAO_ACADEMICA  CO_CURSO  CO_CURSO_POLO  TP_TURNO  \
# 0                         1         1            NaN       3.0
# 1                         1         1            NaN       3.0
# 2                         1         1            NaN       3.0
# 3                         1         1            NaN       3.0
# ...

# %%
alunos_df.iloc[:10, 5:15]
# Out:
#    CO_CURSO_POLO  TP_TURNO  TP_GRAU_ACADEMICO  TP_MODALIDADE_ENSINO  \
# 0            NaN       3.0                1.0                     1
# 1            NaN       3.0                1.0                     1
# 2            NaN       3.0                1.0                     1
# 3            NaN       3.0                1.0                     1
# 4            NaN       3.0                1.0                     1
# 5            NaN       3.0                1.0                     1
# 6            NaN       1.0                1.0                     1
# 7            NaN       3.0                1.0                     1
# 8            NaN       3.0                1.0                     1
# 9            NaN       1.0                1.0                     1
#
#    TP_NIVEL_ACADEMICO CO_CINE_ROTULO                          ID_ALUNO  \
# 0                   1        0421D01  2ECD7C9BEA7DCEBC31B9F2874D454F71
# 1                   1        0421D01  2A9470AC3FC03AD130954809A84BC7D4
# ...

# %%
alunos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043993 entries, 0 to 12043992
# Columns: 105 entries, NU_ANO_CENSO to NU_ANO_INGRESSO
# dtypes: float64(62), int64(40), object(3)
# memory usage: 9.4+ GB

# %% [markdown]
# ## Medicina

# %%
auxiliar_df = pd.read_csv('TB_AUX_CINE_BRASIL.csv', sep='|', encoding='latin-1')
auxiliar_df.head(5)
# Out:
#    CO_CINE_AREA_GERAL NO_CINE_AREA_GERAL  CO_CINE_AREA_ESPECIFICA  \
# 0                   0  Programas básicos                        1
# 1                   0  Programas básicos                        1
# 2                   0  Programas básicos                        1
# 3                   0  Programas básicos                        1
# 4                   0  Programas básicos                        1
#
#   NO_CINE_AREA_ESPECIFICA  CO_CINE_AREA_DETALHADA NO_CINE_AREA_DETALHADA  \
# 0       Programas básicos                      11      Programas básicos
# 1       Programas básicos                      11      Programas básicos
# 2       Programas básicos                      11      Programas básicos
# 3       Programas básicos                      11      Programas básicos
# 4       Programas básicos                      11      Programas básicos
#
#   CO_CINE_ROTULO                                   NO_CINE_ROTULO
# ...

# %%
auxiliar_df[auxiliar_df['NO_CINE_ROTULO'] == 'Medicina']
# Out:
#      CO_CINE_AREA_GERAL NO_CINE_AREA_GERAL  CO_CINE_AREA_ESPECIFICA  \
# 319                   9  Saúde e bem-estar                       91
#
#     NO_CINE_AREA_ESPECIFICA  CO_CINE_AREA_DETALHADA NO_CINE_AREA_DETALHADA  \
# 319                   Saúde                     912               Medicina
#
#     CO_CINE_ROTULO NO_CINE_ROTULO
# 319        0912M01       Medicina

# %%
alunos_df.sample(10)
# Out:
#           NU_ANO_CENSO  CO_IES  TP_CATEGORIA_ADMINISTRATIVA  \
# 7059580           2018     926                            4
# 586856            2018      30                            5
# 12035881          2018   21442                            4
# 8525968           2018    1472                            4
# 11219263          2018    4616                            4
# 1895078           2018     266                            5
# 1623586           2018     167                            5
# 1307580           2018     163                            4
# 2550664           2018     298                            4
# 7980815           2018    1270                            4
#
#           TP_ORGANIZACAO_ACADEMICA  CO_CURSO  CO_CURSO_POLO  TP_TURNO  \
# 7059580                          2    107128            NaN       3.0
# 586856                           1     72712            NaN       3.0
# 12035881                         3   1337996            NaN       3.0
# ...

# %%
type(alunos_df.CO_CURSO[0])
# Out:
# numpy.int64

# %%
list(alunos_df['CO_CURSO'].value_counts().index)
# Out:
# [89380,
#  97980,
#  100305,
#  1268023,
#  98892,
#  87280,
#  102280,
#  97982,
#  87284,
#  100326,
#  97990,
#  121297,
#  79377,
#  121093,
#  111720,
#  97992,
#  100296,
#  1363702,
#  107014,
#  1185928,
#  89309,
#  97573,
#  100324,
#  103338,
#  95295,
#  1115471,
#  1116776,
#  1116879,
#  111270,
#  1442114,
#  7940,
#  1401595,
#  1363701,
#  111726,
#  1185929,
#  107016,
#  1314382,
#  1403882,
#  1401591,
#  99980,
#  1190157,
#  96655,
#  96711,
#  111090,
#  97327,
#  1170317,
#  1119473,
#  1107828,
#  111730,
#  1384586,
#  97986,
#  1190159,
#  1185941,
#  80873,
#  52906,
#  1341021,
#  1190158,
#  87444,
#  113025,
#  1124348,
#  1258528,
#  121026,
#  1300122,
#  94994,
#  89379,
#  1314232,
#  1315358,
#  70442,
#  1203194,
#  1382605,
#  1314234,
#  1374069,
#  8295,
#  122666,
#  1107827,
#  110000,
#  89853,
#  1165118,
#  1315060,
#  96127,
#  1268059,
#  95393,
#  1344519,
#  1190156,
#  1126004,
#  87237,
#  1116842,
#  1108026,
#  1194058,
#  89855,
# ...

# %%
alunos_df[alunos_df['CO_CURSO'] == 912]
# Out:
# Empty DataFrame
# ...

# %%
lista_med_df = pd.read_csv('lista_codigos_cursos_med.csv')
lista_med_df.head()
# Out:
#   Sigla  CO_CURSOS_Medicina      Curso
# 0  UFMT                  12   MEDICINA
# 1  UFMT             1261972   MEDICINA
# 2   UNB                 140   MEDICINA
# 3   UFS                 303   MEDICINA
# 4   UFS             1108153   MEDICINA

# %%
medicina_list = list(lista_med_df.CO_CURSOS_Medicina.value_counts().index)

# %%
alunos_df[alunos_df['CO_CURSO'].isin(medicina_list)]
# Out:
#           NU_ANO_CENSO  CO_IES  TP_CATEGORIA_ADMINISTRATIVA  \
# 3703              2018       1                            1
# 3704              2018       1                            1
# 3705              2018       1                            1
# 3706              2018       1                            1
# 3707              2018       1                            1
# ...                ...     ...                          ...
# 12040603          2018   22514                            4
# 12040604          2018   22514                            4
# 12040605          2018   22514                            4
# 12040606          2018   22514                            4
# 12040607          2018   22514                            4
#
#           TP_ORGANIZACAO_ACADEMICA  CO_CURSO  CO_CURSO_POLO  TP_TURNO  \
# 3703                             1        12            NaN       4.0
# 3704                             1        12            NaN       4.0
# ...

# %%
list(alunos_df.IN_MATRICULA.value_counts().index)
# Out:
# [1, 0]

# %%
alunos_df[alunos_df['CO_CURSO'].isin(medicina_list)][alunos_df['IN_MATRICULA'] == 1]
# Out:
# C:\Users\ROLD003\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#           NU_ANO_CENSO  CO_IES  TP_CATEGORIA_ADMINISTRATIVA  \
# 3703              2018       1                            1
# 3704              2018       1                            1
# 3705              2018       1                            1
# 3706              2018       1                            1
# 3707              2018       1                            1
# ...                ...     ...                          ...
# 12040603          2018   22514                            4
# 12040604          2018   22514                            4
# 12040605          2018   22514                            4
# 12040606          2018   22514                            4
# 12040607          2018   22514                            4
#
# ...

# %% [markdown]
# > Validado com a sinopse estatística do ensino superior 2018. Tanto o Censo quanto na Sinopse Estatística trazem 167,788 alunos de Medicina com matrículas ativas.

# %%
medicina_df = alunos_df[alunos_df['CO_CURSO'].isin(medicina_list)][alunos_df['IN_MATRICULA'] == 1]
medicina_df.head()
# Out:
# C:\Users\ROLD003\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       NU_ANO_CENSO  CO_IES  TP_CATEGORIA_ADMINISTRATIVA  \
# 3703          2018       1                            1
# 3704          2018       1                            1
# 3705          2018       1                            1
# 3706          2018       1                            1
# 3707          2018       1                            1
#
#       TP_ORGANIZACAO_ACADEMICA  CO_CURSO  CO_CURSO_POLO  TP_TURNO  \
# 3703                         1        12            NaN       4.0
# 3704                         1        12            NaN       4.0
# 3705                         1        12            NaN       4.0
# 3706                         1        12            NaN       4.0
# 3707                         1        12            NaN       4.0
#
# ...
